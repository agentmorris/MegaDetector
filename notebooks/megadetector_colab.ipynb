# %% [markdown]
# # Running MegaDetector on camera trap images
#
# [Open this notebook in Colab](https://colab.research.google.com/github/agentmorris/MegaDetector/blob/main/notebooks/megadetector_colab.ipynb)
#
# Adapted from previous versions by [@louis030195](https://github.com/louis030195)
# and [@alsnothome](https://github.com/alsnothome).
#
# Also see the [MegaDetector guide on GitHub](https://github.com/agentmorris/MegaDetector/blob/main/megadetector.md) and the [MegaDetector Python package documentation](https://megadetector.readthedocs.io).
#
# This notebook is designed to load camera trap images that have already been uploaded to Google Drive. If you don't have your own images on Google Drive, this notebook will download some sample images from [LILA](https://lila.science).
#
# MegaDetector output is saved in a .json file in the [MegaDetector output format](https://lila.science/megadetector-output-format). The last cell in this notebook will give you some pointers on how users typically work with MegaDetector output.
#
# Optionally, this notebook will also run [SpeciesNet](https://github.com/google/cameratrapai/) (a species classifier) after running MegaDetector.

# %% [markdown]
# ## Set up the Colab instance to run on a GPU accelerator
#
#
# Navigate to Edit→Notebook Settings and select "GPU" from the "Hardware accelerator" drop-down menu.

# %% [markdown]
# ## Constants

# %%
import os

# Leave this at the default if you are on Colab and you want this notebook to download
# sample images for you.  Otherwise, set this to the folder from which the notebook should read
# your images.

image_folder = "/content/sample-images"
image_folder = "g:/temp/md-colab-test"

# When we visualize results, we will write images to this folder
visualization_folder = '/content/visualized_images'
visualization_folder = "g:/temp/md-colab-test-visualization"

# Which MegaDetector model do you want to run?
#
# MDv5a, MDv5b, and MDv1000-redwood are the largest and most accurate MD models as of
# the time I'm editing this Colab (September 2026).
model_name = 'MDV5A'

# Create subfolder for MD/SpeciesNet visualization
visualization_folder_megadetector = os.path.join(visualization_folder,'megadetector')
visualization_folder_speciesnet = os.path.join(visualization_folder,'speciesnet')

# If you run the "Download sample images" cell, this is where it will get the sample images
sample_dataset_url = \
  "https://lilawildlife.blob.core.windows.net/lila-wildlife/idaho-camera-traps/idaho-camera-traps-sample-images.zip"

# SpeciesNet will (optionally) filter classifications based on a country code.  If you want to run SpeciesNet,
# set this to the three-letter country code for the country where your images come from.
country = 'USA'

# Choose a location for the output JSON files
output_file_megadetector = os.path.join(image_folder,'megadetector_results.json')
output_file_speciesnet = os.path.join(image_folder,'speciesnet_results.json')

# %% [markdown]
# ## Install the MegaDetector Python package
#
# This may take 2-3 minutes.  You may be asked to re-start the Colab runtime, that's OK.

# %%
# !pip install megadetector

# %% [markdown]
# ## Download sample images (optional)
#
# This cell will download a set of sample images from the [Idaho Camera Traps](https://lila.science/datasets/idaho-camera-traps/) dataset.  Skip this if you have your own images.

# %%
from megadetector.utils.url_utils import download_url
from megadetector.utils.path_utils import unzip_file

target_filename = os.path.join(image_folder,sample_dataset_url.split('/')[-1])

download_url(url=sample_dataset_url,
             destination_filename=target_filename,
             force_download=False)

unzip_file(target_filename)

# %% [markdown]
# ## Run the detection script
#
# This step executes the Python script `run_detector_batch.py` from the MegaDetector package. It has three mandatory arguments and one optional:
#
# 1. A MegaDetector model file (this can be a model name, like "MDV5A" or "MDv1000-redwood, or it can be a path to a model file).
# 2. A folder containing images.
# 3. The output JSON file location and name.
#
# If you are in a Colab session with a GPU accelerator, and you are using MDv5a, MDv5b, or MDv1000-redwood (the largest and most accurate MegaDetector models), you should be able to process around four images per second.
#
# Here we are running MegaDetector using python -m to invoke the module as if we were running it at the command line.  You can call this directly via Python code as well; documentation for this module is available [here](https://megadetector.readthedocs.io/en/latest/detection.html#module-megadetector.detection.run_detector_batch).

# %%
print('Processing images from {}'.format(image_folder))

# Run MegaDetector
# !python -m megadetector.detection.run_detector_batch "$model_name" "$image_folder" "$output_file_megadetector" --recursive --output_relative_filenames --quiet

# %% [markdown]
# ## Visualize batch processing script outputs
#
# Here we use the `visualize_detector_output.py` in the `visualization` folder of the MegaDetector repo to see the output of the MegaDetector visualized on our images. It will save images annotated with the results (original images will *not* be modified) to the folder you specify here.

# %%
# !python -m megadetector.visualization.visualize_detector_output "$output_file_megadetector" "$visualization_folder_megadetector" --confidence 0.2 --images_dir "$image_folder"

# %%
# Show the images with bounding boxes in Colab
import os
from PIL import Image

for viz_file_name in os.listdir(visualization_folder_megadetector):
  print(viz_file_name)
  im = Image.open(os.path.join(visualization_folder_megadetector, viz_file_name))
  display(im)

# %% [markdown]
# ## Optional: run SpeciesNet on your images
#
# [SpeciesNet](https://github.com/google/cameratrapai/) is a species classifier that plays nicely with MegaDetector and can be run directly from the MegaDetector Python package.  The next cell (optional) will use the MegaDetector results we've already generated to run SpeciesNet.

# %%
# Install the SpeciesNet Python package
# !pip install speciesnet

# %%
# Run SpeciesNet
# !python -m megadetector.detection.run_md_and_speciesnet "$image_folder" "$output_file_speciesnet" --detections_file "$output_file_megadetector" --country "$country"

# %%
# Render bounding boxes on our images, this time with species labels from SpeciesNet
# !python -m megadetector.visualization.visualize_detector_output "$output_file_speciesnet" "$visualization_folder_speciesnet" --confidence 0.2 --images_dir "$image_folder"

# %%
# Show the images with bounding boxes in Colab
import os
from PIL import Image

for viz_file_name in os.listdir(visualization_folder_speciesnet):
  print(viz_file_name)
  im = Image.open(os.path.join(visualization_folder_speciesnet, viz_file_name))
  display(im)

# %% [markdown]
# # Next steps
#
# Now that you have run MegaDetector on a few images, here are some pointers to help you take advantage of MegaDetector to label your survey images more quickly.
#
# ### Ways to use the output .json in a camera trap image processing workflow
#
# #### 1. Timelapse
#
# [Timelapse](http://saul.cpsc.ucalgary.ca/timelapse/pmwiki.php?n=Main.HomePage) is an open-source tool for annotating camera trap images. We have worked with the Timelapse developer to integrate MegaDetector results into Timelapse, so a user can:
#
# - Select or sort images based on whether they contain animal or people or vehicles.
# - View bounding boxes during additional manual annotation steps
#
# See the [Timelapse Image Recognition Guide](https://saul.cpsc.ucalgary.ca/timelapse/uploads/Guides/TimelapseImageRecognitionGuide.pdf) for more information.
#
# ![Screenshot showing the Timelapse application with MegaDetector output, shown as a bounding box around the detected animal](https://github.com/agentmorris/MegaDetector/blob/main/megadetector/api/batch_processing/integration/images/tl_boxes.jpg?raw=1)
#
#
# #### 2. Separating images into folders that contain animals/people/vehicles/nothing
#
# Some MegaDetector users do image review without Timelapse, by moving the images to separate folders containing animals/people/vehicles/nothing according to MegaDetector output. You can use the script [separate_detections_into_folders.py](https://github.com/agentmorris/MegaDetector/blob/main/megadetector/postprocessing/separate_detections_into_folders.py) for this.
